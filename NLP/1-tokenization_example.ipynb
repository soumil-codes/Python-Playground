# %%
# !pip install nltk

# %%
corpus = """ 
The sun rises in the east. The sun sets in the west, The sun shines on the mountains. The sun shines on the valleys. The sun shines on the clouds """

# %%
print(corpus)
# Out:
#
# The sun rises in the east. The sun sets in the west, The sun shines on the mountains. The sun shines on the valleys. The sun shines on the clouds

# %%
## Tokenization
## sentence <- paragraphs

# %%
nltk.sent_tokenize(corpus)
# Out:
# [' \nThe sun rises in the east.',
#  'The sun sets in the west, The sun shines on the mountains.',
#  'The sun shines on the valleys.',
#  'The sun shines on the clouds']

# %%
import nltk

# %%
tokens = nltk.word_tokenize(corpus)
tokens
# Out:
# ['The',
#  'sun',
#  'rises',
#  'in',
#  'the',
#  'east',
#  '.',
#  'The',
#  'sun',
#  'sets',
#  'in',
#  'the',
#  'west',
#  ',',
#  'The',
#  'sun',
#  'shines',
#  'on',
#  'the',
#  'mountains',
#  '.',
#  'The',
#  'sun',
#  'shines',
#  'on',
#  'the',
#  'valleys',
#  '.',
#  'The',
#  'sun',
#  'shines',
#  'on',
#  'the',
#  'clouds']

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\soumi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\soumi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\soumi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\soumi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\soumi\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\soumi\AppData\Roaming\nltk_data...
# True
