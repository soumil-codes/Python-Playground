# %%
print("hello world")
# Out:
# hello world

# %%
x = 3
y = 2
print(x**y**y)
# Out:
# 81

# %%
import numpy as np

# %%
def pwrpwr(x,y):
    return x**y**y

# %%
def ci(p,r,t):
    cim = (p)(1+r/100)**t
    return cim

# %%
p = pwrpwr(3,3)
p
# Out:
# 7625597484987

# %%
np.
