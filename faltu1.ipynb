# %%
print("hello world")
# Out:
# hello world

# %%
x = 3
y = 2
print(x**y**y)
# Out:
# 81

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def pwrpwr(x,y):
    return x**y**y

# %%
def ci(p,r,t):
    cim = (p)(1+r/100)**t
    return cim

# %%
p = pwrpwr(3,3)
p
# Out:
# 7625597484987

# %%
print('hello')
# Out:
# hello

# %%
"hello" + str(4)
# Out:
# 'hello4'

# %%
ls = [1,3,4,5,6,200]
plt.boxplot(ls)
plt.show()

# %%
normalized_ls = (ls - np.min(ls)) / (np.max(ls) - np.min(ls))
normalized_ls
# Out:
# array([0.        , 0.01005025, 0.01507538, 0.0201005 , 0.02512563,
#        1.        ])

# %%
z_score = (ls - np.mean(ls)) / np.std(ls)
z_score
# Out:
# array([-0.48539516, -0.45804895, -0.44437585, -0.43070274, -0.41702964,
#         2.23555233])
